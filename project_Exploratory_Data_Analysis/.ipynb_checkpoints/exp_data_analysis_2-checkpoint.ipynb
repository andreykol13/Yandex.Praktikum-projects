# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Андрей, привет! Спасибо, что прислал работу во время :)
#
# Предлагаю перейти на ты, чтобы нам было проще взаимодействовать 😊
#
# Меня зовут Евгений, и я буду проверять твой проект)
# Ты проделал большую работу над проектом, однако в любом деле всегда можно можно что-то улучшить. Моя основная цель — не показать, что где—то совершены какие—либо ошибки, а поделиться своим опытом, который поможет тебе в дальнейших работах. Далее в файле ты сможешь увидеть мои комментарии, постарайся учесть их при выполнении следующих заданий.
#
# Мои комментарии обозначены пометкой **Комментарий ревьюера**. Далее в файле ты сможешь найти их в похожих ячейках (если фон комментария <font color=green>зелёный</font> - всё сделано правильно; <font color=orange>оранжевый</font> - есть замечания, но не критично; <font color=red>красный</font> - нужно переделать). Не удаляй эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
#
# Было бы здорово, если бы ты комментировал мои комментарии, это поможет нам быстрее понять друг друга, и при необходимости скорректировать общие действия друг друга.
#
# Можно в том числе рассказывать свои общие впечатления от проекта, нам всегда интересно их услышать 😊
#
# </div>

# %% [markdown]
# <b>Комментарий.</b> Привет, Евгений! Я же буду писать свои комментарии сразу ниже твоих, чтоб ты точно не пропустил ничего :)

# %% [markdown]
# # Проект "Исследование объявлений о продаже квартир"

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Нами получены данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Стоит задача определения рыночной стоимости объектов недвижимости, а конкретнее — установить параметры модели.
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## План выполнения проекта

# %% [markdown]
# 1. <b>Откройте файл с данными и изучите общую информацию</b> (путь к файлу: /datasets/real_estate_data.csv)
# 1. <b>Предобработка данных</b>
#     1. определите и изучите пропущенные значения:
#         1. <i>для некоторых пропущенных значений можно предположить логичную замену. Например, если человек не указал число балконов — скорее всего, их нет. Такие пропуски правильно заменить на 0. Для других типов данных нет подходящего значения на замену. В этом случае правильно оставить эти значения пустыми. Отсутствие значения — тоже важный сигнал, который не нужно прятать;</i>
#         1. <i>заполните пропуски, где это уместно. Опишите, почему вы решили заполнить пропуски именно в этих столбцах и как выбрали значения;</i>
#         1. <i>укажите причины, которые могли привести к пропускам в данных.</i>
#     1. приведите данные к нужным типам:
#         1. <i>поясните, в каких столбцах нужно изменить тип данных и почему.</i>
# 1. <b>Посчитайте и добавьте в таблицу</b>
#     1. цену квадратного метра;
#     1. день недели, месяц и год публикации объявления;
#     1. этаж квартиры; варианты — первый, последний, другой;
#     1. соотношение жилой и общей площади, а также отношение площади кухни к общей.
# 1. <b>Проведите исследовательский анализ данных и выполните инструкции</b>
#     1. Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.
#     1. Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?
#     1. Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.
#     1. Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.
#     1. Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья.
#     1. Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге. Выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.
#     1. Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?
# 1. <b>Напишите общий вывод</b>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Вступление в работу очень важно. Так ты поясняешь то, чему она посвящена. Можно также привести описание используемых столбцов.
#
# </div>

# %% [markdown]
# <b>Комментарий.</b> Я думал, что уместнее рассказать о столбцах далее, в "изучении общей информации". Я так понял, не оч критично, главное — чтобы было.

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
try:
    apts = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
    #apts = pd.read_csv('/Users/Andrejkolesnik/PycharmProjects/project_Exploratory_Data_Analysis/real_estate_data.csv', sep='\t')
    # импорт библиотек и запись данных в датафрейм apts (apartments, рус. "квартиры")
    print(apts.info())
    print(apts.columns)
    display(apts.head(10))
except:
    print('Проблемы со считыванием файла.')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# Из общей информации мы видим, что многие столбцы в данных имеют пропуски, причем их количество неодинаково. Значит, природа появления пропусков, скорее всего, разная. Названия же столбцов состоят лишь из символов латиницы, цифр и символа подчёркивания, что корректно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Хорошо «сырые» данные посмотрели, теперь давай их обработаем.
#
# </div>

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# ### Определите и изучите пропущенные значения

# %% [markdown]
# Стоит сказать, что грамотно будет проверить каждый столбец на предмет очевидно неверных значений (типа отрицательных в столбце количества каких-либо объектов) и все объявления на предмет дубликатов. Однако, в плане проекта эти пункты опущены, поэтому считаем данные корректными, будем анализировать лишь столбцы с пропусками. Начнём с *ceiling_height* — высота потолков в метрах.

# %%
print(apts['ceiling_height'].describe())
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Я считаю, что пропуски в этом столбце возникли из-за простого незнания собственниками всех размеров своей квартиры, в том числе и высоты потолка.
# Просматривая названия столбцов в данных, можно сказать, что нет очевидного варианта, как заменить пропуски. Заменить средним или медианным значением будет некорректно и грубо. Оставим пропуски незаполненными. Следом идет столбец *floors_total* — всего этажей в доме.

# %%
print(apts['floors_total'].describe())
# Out:
# count    23613.000000
# mean        10.673824
# std          6.597173
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# Довольно странно для тех, кто писал объявление, не включить в него этажность здания. Возможно, пропустили строку с количеством этажей в здании при заполнении данных. Или все же пропуски — это частные одноэтажные или двухэтажные дома, и жильцы не видели особого смысла в уточнениях. Не совсем ясно, почему одна замена пропуска будет лучше другой. Можно было бы привязать зависимость и от других переменных (например, расстояние от центра города), но на данном этапе анализа не будем этого делать. Далее *living_area* — жилая площадь в квадратных метрах.

# %%
print(apts['living_area'].describe())
# Out:
# count    21796.000000
# mean        34.457852
# std         22.030445
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Пропусков немного, поэтому причиной тоже может служить либо невнимательность при написании, либо же незнание площади именно жилой части квартиры. Самым логичным решением мог быть подсчёт доли жилой площади в общем площади по всем объявлениям, а затем замена пропусков как раз общей площадью, умноженной на высчитанную долю. Но пока перейдем к *is_apartment* — столбец, показывающий, является ли квартира апартаментами, то есть является ли она нежилым помещением с точки зрения закона.

# %%
print(apts['is_apartment'].value_counts())
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Причина пропусков очевидна — продавец понимает, что не написав ничего, все поймут, что его жилье апартаментами не является. Здесь мы можем все пропуски заменить на False, то есть на то, что квартира апартаментами не является, а является частью жилого фонда.

# %%
apts['is_apartment'] = apts['is_apartment'].fillna(False)
print(apts['is_apartment'].value_counts())
# Out:
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Итак, теперь всё заменили. *kitchen_area* — площадь кухни в квадратных метрах.

# %%
print(apts['kitchen_area'].describe())
# Out:
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Как и в случае с жилой площадью, можно, опираясь на связь с другими столбцами, заполнить пропуски. Но этот вариант не самый очевидный и, возможно, не очень точный. Оставим пропуски незаполненными. Причиной пропусков можно считать то, что некоторые продавцы не знают площади кухни. Это нормально с учётом того, что некоторые не написали размер жилой площади квартиры. Следом идет столбец *balcony* — число балконов.

# %%
print(apts['balcony'].value_counts())
# Out:
# 1.0    4195
# 0.0    3758
# 2.0    3659
# 5.0     304
# 4.0     183
# 3.0      81
# Name: balcony, dtype: int64

# %% [markdown]
# Итак, пропуски здесь заменим на значение 0, так как очевидно, что если человек не указан число балконов, то, скорее всего, в квартире их и нет. В этом и кроется причина пропусков (аналогично столбцу *is_apartment*).

# %%
apts['balcony'] = apts['balcony'].fillna(0)
print(apts['balcony'].value_counts())
# Out:
# 0.0    15277
# 1.0     4195
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81
# Name: balcony, dtype: int64

# %% [markdown]
# Теперь все пропуски в столбце заполнены. Столбец *locality_name* несёт в себе информацию о названии населённого пункта.

# %%
print(apts['locality_name'].value_counts())
# Out:
# Санкт-Петербург           15721
# посёлок Мурино              522
# посёлок Шушары              440
# Всеволожск                  398
# Пушкин                      369
#                           ...
# деревня Трубников Бор         1
# деревня Котлы                 1
# поселок Коробицыно            1
# деревня Нижние Осельки        1
# поселок Гаврилово             1
# Name: locality_name, Length: 364, dtype: int64

# %% [markdown]
# Пропуски здесь либо по невнимательности по заполнению объявления, либо же жильё такое уникальное, что находится вообще вне населённых пунктов. Опять же, здесь нет очевидных замен пропусков. Можно пробовать восстановить значения, исходя из других маркеров местоположения, например, расстояние до центра, количество парков и водоёмов рядом, но мы можем ошибиться, и эта оценка очень сильно может исказить дальнейшие рассуждения. Столбец *airports_nearest* тоже имеет пропуски, он показывает расстояние до ближайшего аэропорта в метрах. Также как и столбец *cityCenters_nearest* — расстояние до центра города в метрах. Здесь пропуски вполне оправданы, мало кто вообще утруждает себя такого рода информацией при подаче объявления. Да и вообще, как считать правильно расстояние до центра? Центр города же не является конкретной точкой.

# %%
print(apts['airports_nearest'].describe())
print(apts['cityCenters_nearest'].describe())
# Out:
# count    18157.000000
# mean     28793.672193
# std      12630.880622
# min          0.000000
# 25%      18585.000000
# 50%      26726.000000
# 75%      37273.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64
# count    18180.000000
# mean     14191.277833
# std       8608.386210
# min        181.000000
# 25%       9238.000000
# 50%      13098.500000
# 75%      16293.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# Снова не очень понятно, как очевидным и понятным образом заменить пропуски в этих столбцах.  Далее идут столбцы с названиями *parks_around3000*, *parks_nearest*, *ponds_around3000* и *ponds_nearest*. Столбцы с названием, содержащим *around3000* имеют смысл количества парков/водоёмов в радиусе 3000 метров, а с названием, содержащим *nearest* — расстояние в метрах до ближайшего объета (парка/водоёма).

# %%
print(apts['parks_around3000'].value_counts())
print(apts['parks_nearest'].describe())
print(apts['ponds_around3000'].value_counts())
print(apts['ponds_nearest'].describe())
# Out:
# 0.0    10106
# 1.0     5681
# 2.0     1747
# 3.0      647
# Name: parks_around3000, dtype: int64
# count    8079.000000
# mean      490.804555
# std       342.317995
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64
# 0.0    9071
# 1.0    5717
# 2.0    1892
# 3.0    1501
# Name: ponds_around3000, dtype: int64
# count    9110.000000
# mean      517.980900
# std       277.720643
# min        13.000000
# 25%       294.000000
# 50%       502.000000
# 75%       729.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64

# %% [markdown]
# Так как человек, оставивший объявление, ничего не сказал нам про парки и водоёмы, то, скорее всего, их и нет в радиусе 3000 метров, причина пропусков в этом случае та же, что и в столбцах *is_apartment* и *balcony*. Поэтому заменим в столбцах *parks_around3000* и *ponds_around3000* пропуски на нулевые значения, а пропуски в других столбцах оставим незаполненными.

# %%
apts['parks_around3000'] = apts['parks_around3000'].fillna(0)
print(apts['parks_around3000'].value_counts())
apts['ponds_around3000'] = apts['ponds_around3000'].fillna(0)
print(apts['ponds_around3000'].value_counts())
# Out:
# 0.0    15624
# 1.0     5681
# 2.0     1747
# 3.0      647
# Name: parks_around3000, dtype: int64
# 0.0    14589
# 1.0     5717
# 2.0     1892
# 3.0     1501
# Name: ponds_around3000, dtype: int64

# %% [markdown]
# Наконец, столбец *days_exposition* показывает нам, сколько дней было размещено объявление от публикации до снятия.

# %%
print(apts['days_exposition'].describe())
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Неясно, как заполнить пропуск в таком столбце. Итак, теперь мы просмотрели все столбцы, имеющие пропуски, и заполнили некоторые из них.

# %% [markdown]
# ### Приведите данные к нужным типам

# %% [markdown]
# Среди уже рассмотренных столбцов нужно изменить тип данных у следующих:
#
# * *floors_total* — всего этажей в доме (с float64 на int64, из-за целочисленности количества этажей в доме);
# * *is_apartment* — является ли апартаментами (с object на bool, из-за бинарной природы столбца);
# * *balcony* — число балконов (с float64 на int64, из-за целочисленности количества балконов);
# * *parks_around3000* — число парков в радиусе 3 км (с float64 на int64, из-за целого количества парков в определённой зоне);
# * *ponds_around3000* — число водоёмов в радиусе 3 км (с float64 на int64, из-за целого количества водоёмов в определённой зоне);
# * *days_exposition* — число дней от размещения до снятия объявления (с float64 на int64, из-за того, что количество дней является целым числом).
#
# Разберём оставшиеся столбцы.
#
# * *total_images* — число фотографий квартиры в объявлении (сейчас int64, нужно int64);
# * *last_price* — цена на момент снятия с публикации (сейчас float64, нужно float64);
# * *total_area* — площадь квартиры в квадратных метрах (сейчас float64, нужно float64);
# * *first_day_exposition* — дата публикации объявления (сейчас object, нужно datetime64);
# * *rooms* — число комнат (сейчас int64, нужно int64);
# * *floor* — этаж (сейчас int64, нужно int64);
# * *studio* — является ли квартира студией (сейчас bool, нужно bool);
# * *open_plan* — есть ли свободная планировка (сейчас bool, нужно bool).
#
# Итого, к первому списку добавляем лишь столбец *first_day_exposition*.

# %%
# apts['floors_total'] = apts['floors_total'].astype(int)
# при вызове будет ошибка

# %% [markdown]
# Из-за наличия пропусков в столбце *floors_total* мы не можем изменить тип данных в нём на целочисленный. Скорее всего, всё-таки, стоит заменить пропуски на неадекватное значение, например, -9999. Тогда конвертация пройдёт успешно. А в дальнешем анализе будем фильтровать эти записи, если будем рассматривать значения этого столбца. Такая ситуация повторится и в столбце *days_exposition*, поэтому в нём сделаем то же самое.

# %%
apts['floors_total'] = apts['floors_total'].fillna(-9999)
apts['days_exposition'] = apts['days_exposition'].fillna(-9999)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Кстати метод `fillna()` можно было бы применить к списку столбцов.
#
# </div>

# %% [markdown]
# Теперь смело можно менять типы данных.

# %%
#apts['floors_total'] = apts['floors_total'].astype(int)
apts['is_apartment'] = apts['is_apartment'].astype(bool)
#apts['balcony'] = apts['balcony'].astype(int)
#apts['parks_around3000'] = apts['parks_around3000'].astype(int)
#apts['ponds_around3000'] = apts['ponds_around3000'].astype(int)
#apts['days_exposition'] = apts['days_exposition'].astype(int)
apts['first_day_exposition'] = pd.to_datetime(apts['first_day_exposition'], 
                                              format='%Y-%m-%dT%H:%M:%S')

cols_to_int = ['floors_total', 'balcony', 'parks_around3000', 
                  'ponds_around3000', 'days_exposition']
for col in cols_to_int:
    apts[col] = apts[col].astype(int)

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера</h2>
#
# Здесь лучше всего подошел бы цикл `for`.
#
# </div>

# %% [markdown]
# <b>Комментарий.</b> Исправлено! Действительно, очень странным решением было писать строку кода для каждого столбца. С опытом придёт :)

# %% [markdown]
# Проверим успешность наших замен.

# %%
print(apts.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23699 non-null int64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 23699 non-null int64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        23699 non-null int64
# ...

# %% [markdown]
# ## Шаг 3. Посчитайте и добавьте в таблицу

# %% [markdown]
# ### Цена квадратного метра

# %% [markdown]
# По очевидной формуле, деля полную стоимость квартиры на её полную площадь, получим цену её квадратного метра.

# %%
apts['sqmeter_price'] = apts['last_price'] / apts['total_area']

# %% [markdown]
# ### День недели, месяц и год публикации объявления

# %% [markdown]
# Вычленим из даты объявления (столбец *first_day_exposition*) день недели, месяц и год публикации.

# %%
apts['weekday_exp'] = apts['first_day_exposition'].dt.weekday # день недели
apts['month_exp'] = apts['first_day_exposition'].dt.month # месяц
apts['year_exp'] = apts['first_day_exposition'].dt.year # год

# %% [markdown]
# ### Этаж квартиры (первый, последний или другой)

# %% [markdown]
# Мы должны будем использовать столбец *floors_total* для опознавания последнего этажа. Так как мы заменили пропуски в нём на отрицательное значение, неясно, в какую категорию относить эти объявления. Но таких проблемных записей у нас всего 86, поэтому все их отнесём к категории этажа "другой".

# %%
def floor_level(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floors_total < 0:
        return 'другой'
    else:
        if floor == 1:
            return 'первый'
        if floor == floors_total:
            return 'последний'
        return 'другой'

apts['floor_level'] = apts.apply(floor_level, axis=1)

# %% [markdown]
# Получилось, теперь есть чёткое разделение этажности на три группы.

# %% [markdown]
# ### Соотношение жилой и общей площади, отношение площади кухни к общей

# %% [markdown]
# Чтобы отыскать эти соотношения, нужно лишь поделить значения в столбце *living_area* (и *kitchen_area*, соответственно) на значение в столбце *total_area*. Однако, у меня есть пропуски в столбцах, которые мы делим. В этом нет проблем, просто на выходе снова будет пропуск вместо значения. Главное то, что нет пропусков в знаменателе нашей дроби, столбце, на который мы делим.

# %%
apts['living_area_frac'] = apts['living_area'] / apts['total_area']
apts['kitchen_area_frac'] = apts['kitchen_area'] / apts['total_area']

# %% [markdown]
# Итак, выведем информацию о данных и первые строки обновлённой таблицы.

# %%
print(apts.info())
display(apts.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 29 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23699 non-null int64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 23699 non-null int64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        23699 non-null int64
# ...

# %% [markdown]
# Кажется, всё сделано верно.

# %% [markdown]
# ## Шаг 4. Проведите исследовательский анализ данных и выполните инструкции

# %% [markdown]
# ### Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра

# %% [markdown]
# Создадим функции для построения гистограмм, чтобы оптимизировать работу с данными.

# %%
def plot_usual(col, plot_title, xlab):
    apts[col].hist()
    plt.title(plot_title)
    plt.xlabel(xlab)
    
def plot_closer(col, col_range, col_bins, plot_title, xlab):
    apts[col].hist(range=col_range, bins=col_bins)
    plt.title(plot_title)
    plt.xlabel(xlab)

# %% [markdown]
# Изучим распределение общей площади квартир с помощью гистограммы.

# %%
plot_usual('total_area', 'Распределение общей площади квартир', 'Общая площадь (кв. м)')

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера</h2>
#
# Не забывай пожалуйста подписывать каждый график. Это важный нюанс каждой работы. Так быстрее понять о чем идёт речь на построенном графике.
#
# </div>

# %% [markdown]
# <b>Комментарий.</b> Хорошо, дальше я это делаю, кажется. А на данном этапе еще додумался, видимо. Исправлено.

# %% [markdown]
# Мы видим явно выбивающиеся большие значения площади, из-за них график неинформативен. Мы видим, что основная доля значений лежит в диапазоне от 0 до 200 квадратных метров. Построим гистограмму только для таких значений, сделав количество столбцов гистограммы, равным 50.

# %%
plot_closer('total_area', (0, 200), 50, 'Распределение общей площади квартир',
           'Общая площадь (кв. м)')

# %% [markdown]
# Мы видим пик графика в районе 40-50 кв. метров. Также теперь мы наблюдаем тяжёлый правый хвост распределения, слева график резко идёт вниз. Достаточно понятно, почему. Слишком близко к нулевому значению подобраться невозможно из очевидных соображений, а вот позволить себе сколь угодно большую квартиру некоторые вполне способны, отсюда и такое разнообразие справа.

# %% [markdown]
# Рассмотрим таким же методом распределение цены квартир.

# %%
plot_usual('last_price', 'Распределение цены квартир', 'Цена квартиры (млн)')
plt.ticklabel_format(axis='x', style='sci', scilimits=(6,6))

# %% [markdown]
# Абсолютно ничего нельзя сказать кроме того, что, как всегда, есть основная масса квартир, а есть сверхбогатые люди, которые продают сверхдорогие квартиры. Изменим масштаб гистограммы.

# %%
plot_closer('last_price', (0, 20e6), 50, 'Распределение цены квартир',
            'Цена квартиры (млн)') # до 20 млн, 50 столбцов
plt.ticklabel_format(axis='x', style='sci', scilimits=(6,6))

# %% [markdown]
# Здесь у нас та же ситуация: справа хвост тянется очень медленно и далеко. По той же причине, что и площадь квартиры. Можно предположить, что площадь квартиры достаточно серьезно влияет на окончательную цену квартиры. Наблюдается пик значений у значений 3-5 млн рублей.

# %% [markdown]
# Рассмотрим распределение числа комнат в квартирах.

# %%
plot_usual('rooms', 'Распределение количества комнат в квартире', 'Количество комнат')

# %% [markdown]
# Видим пик в районе 2-3. У нас есть квартиры, где очень много комнат (больше 10). Узнаем поподробнее статистику по квартирам, где комнат меньше 10.

# %%
plot_closer('rooms', (0, 10), 10, 'Распределение количества комнат в квартире',
            'Количество комнат')

# %% [markdown]
# Оказалось, что больше всего квартир с 1 или 2 комнатами. Чуть меньше квартир с 3 комнатами. Остальных квартир намного меньше.

# %% [markdown]
# Наконец, рассмотрим высоту потолков.

# %%
plot_usual('ceiling_height', 'Распределение высоты потолка в квартире', 'Высота потолка (м)')

# %% [markdown]
# Судя по этой диаграмме, кто-то из продавцов посчитал, что у его квартиры высота потолков больше 20 метров (есть случаи потолков высотой около 100 метров). Естественно, основная группа объявлений лежит намного левее этих значений.

# %%
plot_closer('ceiling_height', (2, 5), 15, 'Распределение высоты потолка в квартире',
            'Высота потолка (м)')

# %% [markdown]
# Теперь мы видим, что большинство квартир имеют потолки в диапазоне от 2.3 до 2.8 метров высотой. Однако, есть значительная доля объявлений, где заявляется высота потолков в районе 3-4 метров. Остальные случаи составляют очень малую долю выборки.

# %% [markdown]
# ### Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго

# %% [markdown]
# Изучим отдельным пунктом время продажи квартиры.

# %%
plot_usual('days_exposition', 'Распределение времени продажи квартиры', 
           'Время продажи квартиры (дн.)')

# %% [markdown]
# Не забываем от том, что мы пометили значением -9999 те записи, где значение было пропущено. Видим, что количество дней нигде не превышает 2000.

# %%
plot_closer('days_exposition', (0, 2000), 100, 'Распределение времени продажи квартиры',
            'Время продажи квартиры (дн.)')

# %% [markdown]
# Теперь мы видим истинное распределение времени продажи квартиры. Пик количества значений приходится на диапазон до 200 дней. Подсчитаем среднее и медианное время продажи квартиры.

# %%
print('Среднее время продажи квартиры',
      apts[apts['days_exposition'] > 0]['days_exposition'].mean().round(2), 'дней')
print('Медианное время продажи квартиры',
      apts[apts['days_exposition'] > 0]['days_exposition'].median(), 'дней')
# Out:
# Среднее время продажи квартиры 180.89 дней
# Медианное время продажи квартиры 95.0 дней

# %% [markdown]
# С учётом того, что правый хвост графика очень массивный, его влияние на оценку среднего будет неоправданно высоким. Оценку медианой будем считать более устойчивой, ей и воспользуемся. Отсюда делаем вывод, что обычно продажа квартиры занимает около 100 дней. Поймём, какие значения стоит считать очень маленькими, а какие — очень большими. Для этого детально рассмотрим хвосты распределения, начнём с левого.

# %%
plot_closer('days_exposition', (0, 5), 5, 'Распределение времени продажи квартиры',
            'Время продажи квартиры (дн.)') # левый хвост

# %% [markdown]
# Видим, что большинство продаж начинаются лишь через 3 дня. Значит, будем считать очень маленькими значения (и продажи считаем очень быстро), меньшие 3. Перейдём к правому хвосту распределения.

# %%
plot_closer('days_exposition', (500, 2000), 50, 'Распределение времени продажи квартиры',
            'Время продажи квартиры (дн.)') # правый хвост

# %% [markdown]
# Здесь тяжело найти чёткую границу для того, чтобы считать значение большим или нет. Думаю, что  1000 дней — это уже достаточно много времени. Поэтому посчитаем значение очень большим (и продажа прошла необычно долго), если оно больше 1000.

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# Давай постараемся автоматизировать построение графиков через цикл `for`.
#
# Почему это важно?
#
# - экономим своё время
# - оптимизируем код
# - делаем работу презентабельнее
#
# Выбери любой участок кода, где это сделать целесообразнее всего.
#
# </div>

# %% [markdown]
# <b>Комментарий.</b> Постарался сделать оптимизацию, правда для меня предпочтительней оказался метод создания функции. Ведь между графиками я хочу писать текст (а в цикле указывать его как часть очередного шага я не хотел, громоздко было бы). А также у некоторых столбцов хотелось потребовать более детализации, больше графиков (не 2, а 3, к примеру). Все прописывать в for не очень-то и хотелось. Надеюсь, что такая оптимизация приемлема.

# %% [markdown]
# ### Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили

# %% [markdown]
# Было решено, что мы оставим лишь объявления с количеством дней продажи от 3 до 1000 включительно.

# %%
new_apts = apts.query('3 <= days_exposition <= 1000')
print(new_apts['days_exposition'].describe())
# Out:
# count    20238.000000
# mean       167.444609
# std        187.603538
# min          3.000000
# 25%         44.000000
# 50%         93.000000
# 75%        222.000000
# max       1000.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Мы убрали около 3.5 тысяч записей, что составляет около 15 процентов от всего числа. Возможно, это покажется большим количеством, но заметим, что большинство отсеянных записей вообще не имели значения в этом поле, лишь пропуски. Строк с данными в этом столбце мы убрали лишь около 300 штук.

# %% [markdown]
# После такого среза данных пересчитаем среднее и медиану в столбце.

# %%
print('После удаления крайних значений в столбце:')
print('Среднее время продажи квартиры',
      new_apts['days_exposition'].mean().round(2), 'дней')
print('Медианное время продажи квартиры',
      new_apts['days_exposition'].median(), 'дней')
# Out:
# После удаления крайних значений в столбце:
# Среднее время продажи квартиры 167.44 дней
# Медианное время продажи квартиры 93.0 дней

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Было бы здорово, если подписывал бы текстом выводимые значения.
#
# </div>

# %% [markdown]
# <b>Комментарий.</b> Торопился, поэтому не обрамил результаты словами для понятности. Сделано!

# %% [markdown]
# Среднее уменьшилось на 17 (и теперь равно 167 дням), а медиана лишь на 3 (теперь 93 дня), что снова говорит о её устойчивости.

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года

# %% [markdown]
# Изучим зависимость цены от площади. Для этого построим диаграмму разброса, где по оси x отложим общую площадь квартиры, а по оси y — цену на неё.

# %%
apts.plot(x='total_area', y='last_price', kind='scatter', alpha=0.3)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.xlabel('Общая площадь (кв. м)')
plt.ylabel('Цена квартиры (млн)')
plt.show()

# %% [markdown]
# Мы помним, что основное облако данных лежит там, где стоимость квартиры составляет не больше 20 млн, а площадь квартиры не более 400 кв. метров. Оставим лишь эту часть графика.

# %%
apts.plot(x='total_area', y='last_price', kind='scatter', 
          ylim=(0, 20e6), xlim=(0,400), alpha=0.1)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.xlabel('Общая площадь (кв. м)')
plt.ylabel('Цена квартиры (млн)')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Здорово что оси у графиков подписаны 👍
#
# </div>

# %% [markdown]
# Видим достаточно чёткую прямую линейную зависимость между столбцами, что согласуется с реальностью. В качестве ещё одного аргумента приведём коэффициент корреляции Пирсона между двумя переменными.

# %%
apts['total_area'].corr(apts['last_price'])
# Out:
# 0.6536750579657244

# %% [markdown]
# Коэффициент корреляции даёт нам понять, что и правда есть зависимость. Она, возможно, будет ещё выше, если считать некоторые объявлениями очень сильными выбросами.

# %% [markdown]
# Ещё один столбец с непрерывными числовыми данными — это расстояние до центра. Проведём те же шаги, что и ранее.

# %%
apts.plot(x='cityCenters_nearest', y='last_price', kind='scatter', alpha=0.3)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.xlabel('Расстояние до центра (м)')
plt.ylabel('Цена квартиры (млн)')
plt.show()

# %% [markdown]
# Сразу уберём из графика выбивающиеся значения.

# %%
apts.plot(x='cityCenters_nearest', y='last_price', kind='scatter', ylim=(0,20e6), alpha=0.1)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.xlabel('Расстояние до центра (м)')
plt.ylabel('Цена квартиры (млн)')
plt.show()

# %% [markdown]
# Кажется, здесь можно судить об отрицательной корреляции между переменными: чем больше расстояние до центра, тем дешевле (в среднем) стоит квартира. Найдём коэффициент корреляции.

# %%
apts['cityCenters_nearest'].corr(apts['last_price'])
# Out:
# -0.20674734874298376

# %% [markdown]
# Действительно, увидели небольшую отрицательную корреляцию. Но она учитывает в себе выбросы на графике.

# %% [markdown]
# Перейдём к анализу зависимости цены квартиры от дискретных переменных. Будем применять для визуализации ящики с усами, каждый из которых будет представлять одно из значений нашей дискретной переменной. Начнём с количества комнат в квартире.

# %%
apts.boxplot(column='last_price', by='rooms')
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.ylim(0, 100e6)
plt.title('')
plt.suptitle('')
plt.xlabel('Количество комнат в квартире')
plt.ylabel('Цена квартиры')
# Out:
# Text(0, 0.5, 'Цена квартиры')

# %% [markdown]
# Можно наблюдать небольшую положительную корреляцию. Найдём коэффициент корреляции.

# %%
apts['rooms'].corr(apts['last_price'])
# Out:
# 0.36334284996489546

# %% [markdown]
# Так и получилось. Изучим зависимость цены квартиры от дня недели размещения объявления.

# %%
apts.boxplot(column='last_price', by='weekday_exp')
plt.ylim(0, 15e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('')
plt.suptitle('')
plt.xlabel('День недели')
plt.ylabel('Цена квартиры')
days_nums = range(1, 8)
plt.xticks(days_nums, ['пн', 'вт', 'ср', 'чт', 'пт', 'сб', 'вс'])
# Out:
# ([<matplotlib.axis.XTick at 0x119483610>,
# ...
#  <a list of 7 Text xticklabel objects>)

# %% [markdown]
# Похоже, нет никакой статистически значимой зависимости.

# %%
apts['weekday_exp'].corr(apts['last_price'])
# Out:
# 0.0015501452176215431

# %% [markdown]
# Действительно, почти идеально нулевая корреляция. Что логично, ведь никому не важно, в какой день недели кто-то опубликовал объявление.

# %% [markdown]
# Повторим те же действия для месяца и года.

# %%
apts.boxplot(column='last_price', by='month_exp')
plt.ylim(0, 15e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('')
plt.suptitle('')
plt.xlabel('Месяц')
plt.ylabel('Цена квартиры')
# Out:
# Text(0, 0.5, 'Цена квартиры')

# %%
apts['month_exp'].corr(apts['last_price'])
# Out:
# 0.0027791287507397252

# %% [markdown]
# Снова корреляция отсутствует.

# %%
apts.boxplot(column='last_price', by='year_exp')
plt.ylim(0, 20e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('')
plt.suptitle('')
plt.xlabel('Год')
plt.ylabel('Цена квартиры')
# Out:
# Text(0, 0.5, 'Цена квартиры')

# %%
apts['year_exp'].corr(apts['last_price'])
# Out:
# -0.04308903619950858

# %% [markdown]
# И для года подачи объявления тоже корреляция, по сути, нулевая. Осталось проверить, как отличаются цены в зависимости от того, на каком этаже находится квартира.

# %%
apts.boxplot(column='last_price', by='floor_level')
plt.ylim(0, 15e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('')
plt.suptitle('')
plt.xlabel('Расположение этажа в доме')
plt.ylabel('Цена квартиры')
# Out:
# Text(0, 0.5, 'Цена квартиры')

# %% [markdown]
# Мы можем наблюдать, что квартира немного проседает в цене, если она находится на первом этаже. Наилучшее положение занимают квартиры, находящиеся ни на первом, ни на последнем этаже. Зависимость цены квартиры от катгории этажа в доме, конечно, есть.

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья

# %% [markdown]
# Итак, названия населённых пунктов хранятся в столбце *locality_name*.

# %%
print(apts['locality_name'].value_counts()[:10])
# Out:
# Санкт-Петербург      15721
# посёлок Мурино         522
# посёлок Шушары         440
# Всеволожск             398
# Пушкин                 369
# Колпино                338
# посёлок Парголово      327
# Гатчина                307
# деревня Кудрово        299
# Выборг                 237
# Name: locality_name, dtype: int64

# %% [markdown]
# Итак, наибольшее число объявлений из Санкт-Петербурга, десятку замыкает Выборг.

# %% [markdown]
# Найдём цену квадратного метра в каждом из этих населённых пунктов, найдём среди них максимальную и минимальную.

# %%
top_towns = apts['locality_name'].value_counts()[:10].index.to_list() # список пунктов
pop_apts = apts.query('locality_name in @top_towns')
(pop_apts.pivot_table(index='locality_name', values='sqmeter_price', aggfunc='mean')
         .sort_values(by='sqmeter_price', ascending=False))
# Out:
#                    sqmeter_price
# locality_name
# Санкт-Петербург    114849.008794
# Пушкин             103125.819291
# деревня Кудрово     92473.547576
# посёлок Парголово   90175.913458
# посёлок Мурино      85752.189195
# посёлок Шушары      78677.364217
# Колпино             75424.579098
# Гатчина             68746.146763
# Всеволожск          68654.473986
# Выборг              58141.909153

# %% [markdown]
# Получили список цен одного квадратного метра в разных местах, причём мы видим, что в Санкт-Петербурге квадратный метр в среднем котируется на уровне 115 тысяч, а в Выборге результат ниже остальных населённых пунктов — 58 тысяч.

# %% [markdown]
# ### Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге. Выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона

# %%
spb_apts = apts[apts['locality_name'] == 'Санкт-Петербург']
spb_apts = spb_apts.dropna(subset=['cityCenters_nearest']) 
# изучаем только те, где есть информация о расстоянии
spb_apts['km_to_center'] = round(spb_apts['cityCenters_nearest'] / 1000).astype(int)
(spb_apts.pivot_table(index='km_to_center', values='last_price', aggfunc='mean')
        .plot(legend=False)
)
plt.title('')
plt.suptitle('')
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.xlabel('Расстояние до центра (км)')
plt.ylabel('Цена квартиры (млн)')
# Out:
# Text(0, 0.5, 'Цена квартиры (млн)')

# %% [markdown]
# Мы можем заметить, что поведение графика сильно меняется после прохождения отметки в 8 км. Будем считать зону центральной, если расстояние до центра города составляет не более 8 км.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Обрати внимание, что основной спад находится в районе 8–9 км и далее происходит длительная стагнация стоимости.
#
# </div>

# %% [markdown]
# <b>Комментарий.</b> Забавно. Ведь сначала я и хотел сделать границу центра по 8 километрам. Видно, что тенденция другая дальше идет, график почти горизонтально идет. Но подумал, что для Питера радиус 8 км от центра – уже перебор. Поэтому и поставил меньше, тем более, как я думаю, тоже причины были. Поменяю на 8 км, посмотрю, как изменятся результаты (интересно же!).

# %% [markdown]
# Выделим сегмент квартир в центре.

# %%
central_apts = spb_apts[spb_apts['km_to_center'] <= 8]

# %% [markdown]
# Теперь проанализируем этот набор. Изучим распределение площади квартир в центре и сравним его с распределением по Санкт-Петербургу в общем.

# %%
central_apts['total_area'].hist(bins=20, range=(0,250))
plt.title('')
plt.suptitle('')
plt.xlabel('Общая площадь (кв. м)')
plt.show()

spb_apts['total_area'].hist(bins=100, range=(0,250))
plt.title('')
plt.suptitle('')
plt.xlabel('Общая площадь (кв. м)')
plt.show()

# %% [markdown]
# Итак, мы наблюдаем, что площадь квартир в центре кажется немного большей, чем по всему городу в среднем. Чтобы это подтвердить, нужно подсчитать среднюю и медианную площадь в каждой группе.

# %%
print('Средняя общая площадь квартиры в центре',
      central_apts['total_area'].mean().round(2))
print('Средняя общая площадь квартиры во всём городе',
      spb_apts['total_area'].mean().round(2))

print('Медианная общая площадь квартиры в центре',
      central_apts['total_area'].median())
print('Медианная общая площадь квартиры во всём городе',
      spb_apts['total_area'].median())
# Out:
# Средняя общая площадь квартиры в центре 90.33
# Средняя общая площадь квартиры во всём городе 64.66
# Медианная общая площадь квартиры в центре 76.0
# Медианная общая площадь квартиры во всём городе 55.0

# %% [markdown]
# Оказывается, площади в центре ощутимо больше, чем в среднем по городу. Хотя это было не так очевидно, ведь в историческом центре обычно достаточно маленькие квартиры. Перейдём к анализу цены.

# %%
central_apts['last_price'].hist(bins=40, range=(0, 200e6))
plt.ticklabel_format(axis='x', style='sci', scilimits=(6,6))
plt.title('В центре')
plt.suptitle('')
plt.xlabel('Цена квартиры (млн)')
plt.show()

spb_apts['last_price'].hist(bins=40, range=(0, 200e6))
plt.title('По всему городу')
plt.suptitle('')
plt.ticklabel_format(axis='x', style='sci', scilimits=(6,6))
plt.xlabel('Цена квартиры (млн)')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Наши действия начинают повторяться, это говорит о том что можно создать например функцию, которая будет строить нужные нам графики.
#
# </div>

# %% [markdown]
# <b>Комментарий.</b> Согласен абсолютно. И я понимаю, как это сделать. Правда, процесс обновления кода будет небыстрым, да и запутаться в мелочах элементарно. А ещё я пропустил 1.5 недели обучения, у меня начался уже следующий проект. А твой комментарий подсвечен зеленым, поэтому пока пойду дальше по коду :)

# %% [markdown]
# Мы видим мощный хвост справа на графике для центра (говорит о том, что много сверхдорогих квартир). Отметим также почти полное отсутствие квартир на участке 0-5 млн в центре, хотя пик приходится на 5-10 млн. Пик также находится на 5-10 млн и по всему городу, но здесь уже квартир ценой в 0-5 млн уже тоже очень много. Подсчитаем среднее и медиану в каждой категории.

# %%
print('Средняя цена квартиры в центре',
      central_apts['last_price'].mean().round(2))
print('Средняя цена квартиры во всём городе',
      spb_apts['last_price'].mean().round(2))

print('Медианная цена квартиры в центре',
      central_apts['last_price'].median())
print('Медианная цена квартиры во всём городе',
      spb_apts['last_price'].median())
# Out:
# Средняя цена квартиры в центре 14180373.18
# Средняя цена квартиры во всём городе 8032783.08
# Медианная цена квартиры в центре 8960000.0
# Медианная цена квартиры во всём городе 5500000.0

# %% [markdown]
# Наблюдаем абсолютное превосходство в цене квартиры в центре. Это вполне соответствует логике.

# %% [markdown]
# Теперь перейдём к анализу числа комнат как в центре, так и в целом по Санкт-Петербургу. Сначала посмотрим на распределение значений в столбце.

# %%
central_apts['rooms'].hist(bins=20, range=(0, 20))
plt.title('В центре')
plt.suptitle('')
plt.xlabel('Количество комнат')
plt.show()

spb_apts['rooms'].hist(bins=20, range=(0, 20))
plt.title('По всему городу')
plt.suptitle('')
plt.xlabel('Количество комнат')
plt.show()

# %% [markdown]
# Итак, мы можем наблюдать, что в центре преобладают квартиры с 2 или 3 комнатами, также немало 4-комнатных квартир. Однако, в целом по городу мы обнаруживаем, что однокомнатных квартир примерно столько же, что и двух- и трёхкомнатных. Доля же 4-комнатных квартир стала много меньше. Убедимся в этом, сравнив средние характеристики для каждой группы.

# %%
print('Среднее количество комнат в квартире в центре',
      central_apts['rooms'].mean().round(2))
print('Среднее количество комнат в квартире во всём городе',
      spb_apts['rooms'].mean().round(2))

print('Медианное количество комнат в квартире в центре',
      central_apts['rooms'].median())
print('Медианное количество комнат в квартире во всём городе',
      spb_apts['rooms'].median())
# Out:
# Среднее количество комнат в квартире в центре 2.76
# Среднее количество комнат в квартире во всём городе 2.17
# Медианное количество комнат в квартире в центре 3.0
# Медианное количество комнат в квартире во всём городе 2.0

# %% [markdown]
# Абсолютно те же выводы мы получаем и по новым данным.

# %% [markdown]
# Наконец, изучим распределение высоты потолков. Мы делали это ранее для всего набора данных. Теперь же проведём исследование дважды: сначала по центральной зоне, которую мы выделили до этого, а затем по всем объявлениям в городе Санкт-Петербурге.

# %%
central_apts['ceiling_height'].hist(bins=20, range=(2,6)) 
# сразу акцентируем внимание на содержательную часть графика
plt.title('В центре')
plt.suptitle('')
plt.xlabel('Высота потолка (м)')
plt.show()

spb_apts['ceiling_height'].hist(bins=20, range=(2,6)) 
plt.title('По всему городу')
plt.suptitle('')
plt.xlabel('Высота потолка (м)')
plt.show()

# %% [markdown]
# Этот столбец тоже даёт некоторое представление о различиях квартир центре города и в квартирах по всему Санкт-Петербургу. Центральные квартиры имеют типичную высоту потолков на уровне более 3 метров, тогда как по городу в общем, такой показатель держится в районе 2.5 метров. Подкрепим эти утверждения строго с помощью среднего и медианы в столбцах.

# %%
print('Средняя высота потолков в квартире в центре',
      central_apts['ceiling_height'].mean().round(2))
print('Средняя высота потолков в квартире во всём городе',
      spb_apts['ceiling_height'].mean().round(2))

print('Медианная высота потолков в квартире в центре',
      central_apts['ceiling_height'].median())
print('Медианная высота потолков в квартире во всём городе',
      spb_apts['ceiling_height'].median())
# Out:
# Средняя высота потолков в квартире в центре 3.13
# Средняя высота потолков в квартире во всём городе 2.8
# Медианная высота потолков в квартире в центре 3.0
# Медианная высота потолков в квартире во всём городе 2.7

# %% [markdown]
# Действительно, и медиана, и среднее дают понять, что разница в категориях составляет примерно полметра, если речь идёт про высоту потолков в квартире.

# %% [markdown]
# Теперь в обеих группах отыщем факторы, влияющие на стоимость квартиры. Принцип тот же, что и раньше — построить "ящик с усами" для дискретных переменных и диаграмму разброса для непрерывных, а также для всех предложенных столбцов подсчитать корреляцию со столбцом цены квартиры. Сначала узнаем, влияет ли где-то (в центре и/или по всему городу) количество комнат на цену квартиры.

# %%
central_apts.boxplot(column='last_price', by='rooms')
plt.ylim(0, 100e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('В центре')
plt.suptitle('')
plt.xlabel('Количество комнат в квартире')
plt.ylabel('Цена квартиры')
plt.show()

spb_apts.boxplot(column='last_price', by='rooms')
plt.ylim(0, 100e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('По всему городу')
plt.suptitle('')
plt.xlabel('Количество комнат в квартире')
plt.ylabel('Цена квартиры')
plt.show()

print('Корреляция между количеством комнат в квартире и ценой квартиры в центре города \n', 
      central_apts['rooms'].corr(apts['last_price']))
print('Корреляция между количеством комнат в квартире и ценой квартиры по всему городу \n', 
      spb_apts['rooms'].corr(apts['last_price']))
# Out:
# Корреляция между количеством комнат в квартире и ценой квартиры в центре города
#  0.34054074808961077
# Корреляция между количеством комнат в квартире и ценой квартиры по всему городу
#  0.37128918133242395

# %% [markdown]
# Мы можем сделать следующий вывод: количество комнат действительно немного влияет на цену квартиры как в центре, так и по всему городу (чем больше комнат, тем выше цена), причём в целом по Санкт-Петербургу зависимость сильнее.

# %% [markdown]
# Изучим зависимость цены от того, на каком этаже находится квартира.

# %%
central_apts.boxplot(column='last_price', by='floor_level')
plt.ylim(0, 20e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('В центре')
plt.suptitle('')
plt.xlabel('Расположение этажа в доме')
plt.ylabel('Цена квартиры')
plt.show()

spb_apts.boxplot(column='last_price', by='floor_level')
plt.ylim(0, 20e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('По всему городу')
plt.suptitle('')
plt.xlabel('Расположение этажа в доме')
plt.ylabel('Цена квартиры')
plt.show()

# %% [markdown]
# Итак, из-за типа значений в столбце этажа мы не можем подсчитать корреляцию Пирсона. Однако, по "ящику" мы по-прежнему можем сделать некоторые выводы. В частности, что очевидно, цены на квартиры в центре серьёзно отличаются от среднего по городу. Что важнее, так это то, что ни в центре, ни по городу в целом не очень котируют первый этаж (последний тоже, но в меньшей степени). Но если в среднем по городу квартира на первом этаже ценится меньше квартиры на "другом" этаже примерно на 15 процентов, то в центре эта "скидка" составляет существенные 30 процентов. Пожалуй, это логично, ведь квартиры на первом этаже в центре города означают сосуществование с торговыми точками (и это в лучшем случае). Это мало кому нравится.

# %% [markdown]
# Ещё один заявленный фактор, который нуждается в анализе — это расстояние до центра.

# %%
central_apts.plot(x='cityCenters_nearest', y='last_price', kind='scatter', alpha=0.3, 
                 ylim=(0, 40e6))
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('В центре')
plt.suptitle('')
plt.xlabel('Расстояние до центра (м)')
plt.ylabel('Цена квартиры')
plt.show()

spb_apts.plot(x='cityCenters_nearest', y='last_price', kind='scatter', alpha=0.3, 
                 ylim=(0, 40e6))
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('По всему городу')
plt.suptitle('')
plt.xlabel('Расстояние до центра (м)')
plt.ylabel('Цена квартиры')
plt.show()

print('Корреляция между расстоянием до центра и ценой квартиры в центре города \n', 
      central_apts['cityCenters_nearest'].corr(apts['last_price']))
print('Корреляция между расстоянием до центра и ценой квартиры по всему городу \n', 
      spb_apts['cityCenters_nearest'].corr(apts['last_price']))
# Out:
# Корреляция между расстоянием до центра и ценой квартиры в центре города
#  -0.07814158858803319
# Корреляция между расстоянием до центра и ценой квартиры по всему городу
#  -0.2595074646319885

# %% [markdown]
# Как и ожидается, в самом центре города уже не слишком важно расстояние до географического центра города, ведь 2 километра до него или 3 — это неважно, ведь транспортные службы отлично справляются на таком расстоянии. Коэффициент корреляции же для всего города сразу имеет большее абсолютное значение, то есть зависимость цены от расстояния здесь играет намного большую роль.

# %% [markdown]
# Наконец, узнаем связь цены квартиры с дата размещения объявления. Здесь у нас три подпункта — связь с днём недели, месяцем и годом.

# %%
central_apts.boxplot(column='last_price', by='weekday_exp')
plt.ylim(0, 20e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('В центре')
plt.suptitle('')
plt.xlabel('День недели')
plt.ylabel('Цена квартиры')
days_nums = range(1, 8)
plt.xticks(days_nums, ['пн', 'вт', 'ср', 'чт', 'пт', 'сб', 'вс'])
plt.show()

spb_apts.boxplot(column='last_price', by='weekday_exp')
plt.ylim(0, 20e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('По всему городу')
plt.suptitle('')
plt.xlabel('День недели')
plt.ylabel('Цена квартиры')
days_nums = range(1, 8)
plt.xticks(days_nums, ['пн', 'вт', 'ср', 'чт', 'пт', 'сб', 'вс'])
plt.show()

print('Корреляция между днём недели подачи объявления и ценой квартиры в центре города \n', 
      central_apts['weekday_exp'].corr(apts['last_price']))
print('Корреляция между днём недели подачи объявления и ценой квартиры по всему городу \n', 
      spb_apts['weekday_exp'].corr(apts['last_price']))
# Out:
# Корреляция между днём недели подачи объявления и ценой квартиры в центре города
#  0.02071796873830608
# Корреляция между днём недели подачи объявления и ценой квартиры по всему городу
#  0.006979976439581736

# %%
central_apts.boxplot(column='last_price', by='month_exp')
plt.ylim(0, 15e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('В центре')
plt.suptitle('')
plt.xlabel('Месяц')
plt.ylabel('Цена квартиры')
plt.show()

spb_apts.boxplot(column='last_price', by='month_exp')
plt.ylim(0, 15e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('По всему городу')
plt.suptitle('')
plt.xlabel('Месяц')
plt.ylabel('Цена квартиры')
plt.show()

print('Корреляция между месяцем подачи объявления и ценой квартиры в центре города \n', 
      central_apts['month_exp'].corr(apts['last_price']))
print('Корреляция между месяцем подачи объявления и ценой квартиры по всему городу \n', 
      spb_apts['month_exp'].corr(apts['last_price']))
# Out:
# Корреляция между месяцем подачи объявления и ценой квартиры в центре города
#  -0.00418866815054201
# Корреляция между месяцем подачи объявления и ценой квартиры по всему городу
#  -0.0005406531632516008

# %%
central_apts.boxplot(column='last_price', by='year_exp')
plt.ylim(0, 30e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('В центре')
plt.suptitle('')
plt.xlabel('Год')
plt.ylabel('Цена квартиры')
plt.show()

spb_apts.boxplot(column='last_price', by='year_exp')
plt.ylim(0, 30e6)
plt.ticklabel_format(axis='y', style='sci', scilimits=(6,6))
plt.title('По всему городу')
plt.suptitle('')
plt.xlabel('Год')
plt.ylabel('Цена квартиры')
plt.show()

print('Корреляция между годом подачи объявления и ценой квартиры в центре города \n', 
      central_apts['year_exp'].corr(apts['last_price']))
print('Корреляция между годом подачи объявления и ценой квартиры по всему городу \n', 
      spb_apts['year_exp'].corr(apts['last_price']))
# Out:
# Корреляция между годом подачи объявления и ценой квартиры в центре города
#  -0.04709669193181639
# Корреляция между годом подачи объявления и ценой квартиры по всему городу
#  -0.04532934039941756

# %% [markdown]
# Здесь всё понятно: и из графиков, и из всех значений корреляции. Вывод один — ни день недели, ни месяц, ни год размещения объявления никак не коррелирует (и, по всей видимости, не связан) с ценой на квартиру как в центре, так и по всему городу.

# %% [markdown]
# ## Шаг 5. Напишите общий вывод

# %% [markdown]
# В ходе выполнения проекта было выполнено несколько задач и получены ответы на поставленные вопросы.
#
# 1. Произведена предобработка данных, включающая в себя заполнение некоторых пропусков с указанием возможных причин их появления, а также приведение всех данных к нужным типам с аргументацией надобности этого;
#
# 1. В таблицу были добавлены новые столбцы, которые существенно помогли в дальнейшем анализе данных, проведена категоризация данных в одном из столбцов;
#
# 1. Изучено распределение значений некоторых столбцов, которые могут быть факторами, влияющими на цену продажи квартиры;
#
# 1. Получены развернутые и аргументированные выводы о влиянии некоторых факторов на цену квартиры:
#
#     1. Среди всех объявлений цена квартиры зависит от её общей площади (коэффицент корреляции Пирсона 0.654), расстояние до центра (-0.207), количество комнат (0.363). Вместе же с этим не было найдено статистически значимой корреляции между ценой квартиры и днём недели(0.002), месяцем (0.003) и годом подачи объявления (-0.043). Также было выяснено, что цена на квартиры существенно ниже, если она расположена на первом этаже (на 20 процентов) и на последнем (10%);
#     1. Среди десяти самых популярных населённых пунктов по количеству объявлений самый дорогой квадратный метр жилой недвижимости расположен в Санкт-Петербурге (115 тысяч), а самый дешёвый — в Выборге (58 тысяч);
#     1. Была установлена условная граница "центральной зоны" Санкт-Петербурга — 8 км от центра;
#     1. При сравнении квартир в центре и по всему Санкт-Петербургу были обнаружены следующие сходства и различия в средних значениях по столбцам:
#         1. Общая площадь квартиры в центре намного больше, чем по городу в целом (среднее 90.3 кв. м в центре против 64.7 кв. м по городу, медиана 76 против 55);
#         1. Цены квартир в центре также разительно отличаются от цен по городу (среднее значение: 14.2 млн в центре, 8 млн по городу; медиана: 9 млн в центре, 5.5 млн по городу);
#         1. Количество комнат в центральной квартире больше, чем в среднем по городу (2.8 против 2.2);
#         1. Наконец, высота потолков в центре больше, чем в городе в общем (медианное значение 3 метра в центре против 2.7 по городу);
#     1. После анализа взаимосвязи цены квартиры с различными факторами отдельно в центре и отдельно по всему городу, сделаны следующие выводы:
#         1. Количество комнат влияет на цену квартиры как в центре (корреляция 0.34), так и по всему городу (0.37), зависимость примерно одинаково высокая;
#         1. Этаж также влияет на цену квартиры в обеих категориях. По городу в общем квартира на первом этаже ценится меньше на 15%, чем квартира в "промежуточном" этаже. Однако, различия становятся больше в центральном районе, там разница в среднем достигает 30%;
#         1. Расстояние до центра города почти не влияет на цену квартиры в центральном районе (-0.08), в отличие от всего города в целом (-0.26);
#         1. День недели, месяц и год подачи объявления не влияют на цену квартиры ни в центре, ни по всему городу.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Выводы логичны и понятны.
#
# </div>

# %% [markdown]
# <b>Комментарий.</b> Чуть подправил выводы, ведь центральная зона изменилась. Но принципиально мало что изменилось.
